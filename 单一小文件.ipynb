# %%
import pandas as pd

# %%
header = [ 
"id",
"click",
"hour",  
"C1",
"banner_pos",
"site_id",
"site_domain",
"site_category",
"app_id",
"app_domain",
"app_category",
"device_id",
"device_ip",
"device_model",
"device_type",
"device_conn_type",
"C14",
"C15",
"C16",
"C17",
"C18",
"C19",
"C20",
"C21"
]
df = pd.read_csv("./dataProcess/split35.csv", names = header)
df.describe()
# Out:
#                  id          click          hour             C1  \
# count  7.000000e+05  700000.000000  7.000000e+05  700000.000000
# mean   9.213432e+18       0.185429  1.410270e+07    1004.827507
# std    5.391664e+18       0.388645  2.331104e+01       1.623135
# min    3.178635e+13       0.000000  1.410262e+07    1001.000000
# 25%    4.507218e+18       0.000000  1.410270e+07    1005.000000
# 50%    9.066042e+18       0.000000  1.410270e+07    1005.000000
# 75%    1.397912e+19       0.000000  1.410270e+07    1005.000000
# max    1.844672e+19       1.000000  1.410270e+07    1012.000000
#
#           banner_pos    device_type  device_conn_type            C14  \
# count  700000.000000  700000.000000     700000.000000  700000.000000
# mean        0.286223       0.924853          0.202137   18690.267993
# std         0.491353       0.566995          0.686304    4588.143627
# min         0.000000       0.000000          0.000000     375.000000
# ...

# %%
df.shape
df.head(100)
# Out:
#               id  click      hour    C1  banner_pos   site_id site_domain  \
# 0   1.248387e+19      0  14102623  1005           1  e151e245    7e091613
# 1   1.248417e+19      0  14102623  1005           0  6256f5b4    28f93029
# 2   1.248428e+19      0  14102623  1005           0  85f751fd    c4e18dd6
# 3   1.248432e+19      1  14102623  1005           1  e151e245    7e091613
# 4   1.248451e+18      0  14102623  1005           0  85f751fd    c4e18dd6
# 5   1.248465e+19      0  14102623  1005           1  85f751fd    c4e18dd6
# 6   1.248466e+19      0  14102623  1005           0  85f751fd    c4e18dd6
# 7   1.248482e+19      0  14102623  1005           0  85f751fd    c4e18dd6
# 8   1.248484e+19      1  14102623  1005           0  cf49edec    9289701a
# 9   1.248501e+18      0  14102623  1005           0  85f751fd    c4e18dd6
# 10  1.248521e+19      1  14102623  1005           1  5b4d2eda    16a36ef3
# 11  1.248531e+19      0  14102623  1005           1  e151e245    7e091613
# ...

# %%
#df.isnull().any().sum()
d = df['device_conn_type']

# %%
d.drop_duplicates()
# Out:
# 0      0
# 6      3
# 14     2
# 659    5
# Name: device_conn_type, dtype: int64

# %% [markdown]
# ## 猜想所有文件都不会有空值
# ## go处理后发现没有空值

# %%
df["C14"].sort_values()[:100]
# Out:
# 482319    375
# 31899     375
# 571101    375
# 483981    375
# 571096    375
# 483943    375
# 152656    375
# 622975    375
# 13313     375
# 431266    375
# 460124    375
# 640890    375
# 511720    375
# 511734    375
# 246077    375
# 52758     375
# 346095    375
# 511583    375
# 571197    375
# 41365     375
# 511271    375
# 205642    375
# 571450    375
# 459968    375
# 152480    375
# 374022    375
# 3971      375
# 431213    375
# 120696    375
# 640705    375
#          ...
# 374591    375
# 483836    375
# 205856    375
# 187658    375
# 13383     375
# 692672    375
# 570884    375
# 511240    375
# 675699    375
# 571531    375
# 280930    375
# 32207     375
# 104597    375
# 266219    375
# 312646    375
# 12998     375
# 4071      375
# 676046    375
# 104541    375
# 69535     375
# 188272    375
# 346443    375
# 432270    375
# 510873    375
# 484316    375
# 640346    375
# 312624    375
# 226683    375
# 104616    375
# 226582    375
# ...

# %% [markdown]
# # 根据kaggle c14-c21 为分类， 猜测是1-max 整数范围内的分类
# # 5kw * 8 / 1024 * 1024 == 380MB 左右，
# # 用go 读取这些分类， 分别统计每个分类取值范围

# %%
50000009 * 8 /(1024*1024)
# Out:
# 381.4697952270508

# %%
set(df["C14"].sort_values())
# Out:
# {375,
#  376,
#  377,
#  380,
#  381,
#  4687,
#  5296,
#  5299,
#  6360,
#  6361,
#  6362,
#  6364,
#  6365,
#  6366,
#  6392,
#  6393,
#  6397,
#  6398,
#  6399,
#  6400,
#  6401,
#  6402,
#  6557,
#  6558,
#  6559,
#  6560,
#  6563,
#  6990,
#  6991,
#  6992,
#  6993,
#  7023,
#  7024,
#  7693,
#  7698,
#  7699,
#  7700,
#  7701,
#  7702,
#  7707,
#  7708,
#  7709,
#  7711,
#  7712,
#  7714,
#  8330,
#  8334,
#  8434,
#  8994,
#  8995,
#  8996,
#  9014,
#  9015,
#  9016,
#  9236,
#  9248,
#  9436,
#  9437,
#  9438,
#  9461,
#  9478,
#  9798,
#  9803,
#  9805,
#  10289,
#  10531,
#  10532,
#  10533,
#  10534,
#  10535,
#  10536,
#  10898,
#  11142,
#  11144,
#  11145,
#  11188,
#  11189,
#  11190,
#  11191,
#  11192,
#  11193,
#  11265,
#  11267,
#  11268,
#  11323,
#  11325,
#  12469,
#  12470,
#  12471,
#  12472,
#  12477,
#  13643,
#  13644,
#  13777,
#  13778,
#  13779,
#  13780,
#  13781,
#  13782,
#  13783,
#  14136,
#  14140,
#  14141,
#  14142,
#  14198,
#  14202,
# ...

# %%
# c1file = pd.read_csv("./featureCategoryRange/C1.txt", header=None)
c1file = pd.read_csv("./dataProcess/split01.csv", header=None)

# %%
c1file.describe()
# Out:
#                  0              1             2              3   \
# count  6.999990e+05  699999.000000  6.999990e+05  699999.000000
# mean   9.286516e+18       0.164449  1.410210e+07    1005.070882
# std    5.223484e+18       0.370683  1.173748e+00       1.095087
# min    9.984920e+12       0.000000  1.410210e+07    1001.000000
# 25%    4.792727e+18       0.000000  1.410210e+07    1005.000000
# 50%    9.695073e+18       0.000000  1.410210e+07    1005.000000
# 75%    1.352953e+19       0.000000  1.410210e+07    1005.000000
# max    1.844670e+19       1.000000  1.410210e+07    1012.000000
#
#                   4              14             15             16  \
# count  699999.000000  699999.000000  699999.000000  699999.000000
# mean        0.225563       1.031254       0.214812   18135.314745
# std         0.455292       0.471839       0.657126    3410.726012
# min         0.000000       0.000000       0.000000     375.000000
# ...

# %%
c1file[17].max()
# Out:
# 1024

# %%
c1file[17].min()
# Out:
# 120

# %%
set(c1file[17])
# Out:
# {120, 216, 300, 320, 480, 728, 768, 1024}
